# %%
import numpy as np

# %%
data = np.genfromtxt("sub_94.csv", delimiter = ",", skip_header = 1)
data
# Out:
# array([[ 0.31244551, -1.12434543, -0.30823005, ..., -0.29373551,
#         -0.41234676,  0.        ],
#        [ 0.32463263, -1.17725029, -0.30594806, ..., -0.27786867,
#         -0.41422172,  0.        ],
#        [ 0.33954093, -1.2008495 , -0.30301181, ..., -0.26078339,
#         -0.41949616,  0.        ],
#        ...,
#        [-0.46335934, -0.75548428,  0.1045134 , ..., -0.20098651,
#          0.03723721,  2.        ],
#        [-0.30864262, -0.89934126,  0.16604842, ..., -0.0577188 ,
#         -0.04417656,  2.        ],
#        [-0.17459699, -1.01045885,  0.21958597, ...,  0.05657771,
#         -0.13156837,  2.        ]])

# %%
print(np.shape(data))
# Out:
# (6816, 9)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (14,10))
plt.plot(list(range(6816)), data)
plt.show()
